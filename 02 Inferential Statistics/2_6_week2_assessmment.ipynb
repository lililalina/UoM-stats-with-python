# %% [markdown]
# <a href="https://colab.research.google.com/github/lililalina/UoM-stats-with-python/blob/main/02%20Inferential%20Statistics/2_6_week2_assessmment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Confidence intervals in python**
#
# In this assessment, you will look at data from a study on toddler sleep habits.
#
# The confidence intervals you create and the questions you answer in this Jupyter notebook will be used to answer questions in the following graded assignment.

# %%
import numpy as np
import pandas as pd
from scipy.stats import t
pd.set_option('display.max_columns', 30) # set so can see all columns of the DataFrame

# %% [markdown]
# Your goal is to analyse data which is the result of a study that examined differences in a number of sleep variables between napping and non-napping toddlers. Some of these sleep variables included: Bedtime (lights-off time in decimalized time), Night Sleep Onset Time (in decimalized time), Wake Time (sleep end time in decimalized time), Night Sleep Duration (interval between sleep onset and sleep end in minutes), and Total 24-Hour Sleep Duration (in minutes). Note: Decimalized time is the representation of the time of day using units which are decimally related.
#
# The 20 study participants were healthy, normally developing toddlers with no sleep or behavioral problems. These children were categorized as napping or non-napping based upon parental report of children’s habitual sleep patterns. Researchers then verified napping status with data from actigraphy (a non-invasive method of monitoring human rest/activity cycles by wearing of a sensor on the wrist) and sleep diaries during the 5 days before the study assessments were made.
#
# You are specifically interested in the results for Bedtime.
#
# Reference: Akacem LD, Simpkin CT, Carskadon MA, Wright KP Jr, Jenni OG, Achermann P, et al. (2015) The Timing of the Circadian Clock and Sleep Differ between Napping and Non-Napping Toddlers. PLoS ONE 10(4): e0125181. https://doi.org/10.1371/journal.pone.0125181

# %%
# Import the data
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/UoM stats with python/napping.csv")

# %%
# First, look at the DataFrame to get a sense of the data
df
# Out:
#                               id     sex  age (months)  dlmo time  \
# 0                              1  female          33.7      19.24
# 1                              2  female          31.5      18.27
# 2                              3    male          31.9      19.14
# 3                              4  female          31.6      19.69
# 4                              5  female          33.0      19.52
# 5                              6  female          36.2      18.22
# 6                              7    male          36.3      19.28
# 7                              8    male          30.0      21.06
# 8                              9    male          33.2      19.38
# 9                             10  female          37.1      19.93
# 10                            11    male          32.9      18.79
# 11                            12  female          35.0      19.65
# 12                            13    male          35.1      19.83
# ...

# %% [markdown]
# Question: What value is used in the column 'napping' to indicate a toddler takes a nap? (see reference article)
#
# napping = 1, non napping = 0
#
# Question: What is the overall sample size  n ? What is the sample size for toddlers who nap,  n1 , and toddlers who don't nap,  n2 ?
#
# n1 or napping = 15, n2 or non napping = 5

# %% [markdown]
# ### Average bedtime confidence interval for napping and non napping toddlers
# Create two 95% confidence intervals for the average bedtime, one for toddler who nap and one for toddlers who don't.

# %%
# Isolate the column napping and night bedtime
df_bedtime = df[['napping', 'night bedtime']]
df_bedtime = df_bedtime.groupby(['napping']).agg({'night bedtime':[ np.mean, np.std, np.size]})
df_bedtime
# Out:
#         night bedtime
#                  mean       std size
# napping
# 0.0            19.590  0.507592    5
# 1.0            20.304  0.591062   15

# %%
# Average bedtime for toddlers who nap and its 95% CI
n1 = df_bedtime.iloc[1,2]
nap_mean_bedtime = df_bedtime.iloc[1,0]
nap_s_bedtime = df_bedtime.iloc[1,1] 
nap_se_mean_bedtime = nap_s_bedtime/(np.sqrt(n1))

# t value for n = 15, CI 95%
nap_t_star = t.ppf(1- ((100-95)/2/100), 14)

# Calculate the lcb and ucb
lcb_bedtime_nap = nap_mean_bedtime - nap_se_mean_bedtime*nap_t_star
ucb_bedtime_nap = nap_mean_bedtime + nap_se_mean_bedtime*nap_t_star

print('Average bedtime for toddlers who nap:', nap_mean_bedtime, "±", nap_se_mean_bedtime)
print('Lower bound:', lcb_bedtime_nap, "Upper bound:", ucb_bedtime_nap)
# Out:
# Average bedtime for toddlers who nap: 20.304 ± 0.15261155170656576
# Lower bound: 19.976680775477412 Upper bound: 20.631319224522585

# %%
# Average bedtime for toddlers who do not nap and its 95% CI
n2 = df_bedtime.iloc[0,2]
no_nap_mean_bedtime = df_bedtime.iloc[0,0]
no_nap_s_bedtime = df_bedtime.iloc[0,1] 
no_nap_se_mean_bedtime = no_nap_s_bedtime/(np.sqrt(n2))

# t value for n = 5, CI 95%
no_nap_t_star = t.ppf(1- ((100-95)/2/100), 4)

# Calculate the lcb and ucb
lcb_bedtime_nonap = no_nap_mean_bedtime - no_nap_se_mean_bedtime*no_nap_t_star
ucb_bedtime_nonap = no_nap_mean_bedtime + no_nap_se_mean_bedtime*no_nap_t_star

print('Average bedtime for toddlers who do not nap:', no_nap_mean_bedtime, "±",no_nap_se_mean_bedtime)
print('Lower bound:', lcb_bedtime_nonap, "Upper bound:", ucb_bedtime_nonap)
# Out:
# Average bedtime for toddlers who do not nap: 19.59 ± 0.22700220263248558
# Lower bound: 18.959740845631917 Upper bound: 20.220259154368083

# %% [markdown]
# #### Notes for t value
# Example: to find the $t^*$ for a 90% confidence interval, we want $t^*$ such that 90% of the density of the $t$ distribution lies between $-t^*$ and $t^*$.
#
# Or in other words if $X \sim t(df)$:
#
# P($-t^*$ < X < $t^*$) = .90
#
# Which, because the $t$ distribution is symmetric, is equivalent to finding $t^*$ such that:
#
# P(X < $t^*$) = .95
#
# (0.95 = 1 - (1 - confidence) / 2 = 1 - 0.1 / 2 = 1 - 0.05)
#
# So the $t^*$ for a 90% confidence interval, and lets say df=10, will be:
#
# t_star = t.ppf(.95, df=10)
